# %% [markdown]
# ## Data Visualization in Python

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Line Plot

# %%
plt.plot([2,4,6,7,8,12,17],[4,8,12,14,16,18,19])

# %%
# ?plt.plot

# %%
plt.plot([2,4,6,7,8,12,17],[4,8,12,14,16,18,15],marker='s',color='#45C4B0',linestyle='--')

# %%
plt.plot([2,4,6,7,8,12,17],[4,8,12,14,16,18,15],marker='s',color='#45C4B0',linestyle='-.')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Our first Plot')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot([2,4,6,7,8,12,17],[4,8,12,14,16,18,15],marker='x',color='#45C4B0',linestyle='-.')
plt.xlabel('x-axis')

plt.grid()
plt.ylabel('y-axis')
plt.title('Our first Plot')
plt.savefig('my_line_plot.png');

# %%
gas = pd.read_csv(r"C:\Users\MTL9\Documents\gtl_ds\Python Scripts\gas_prices.csv")
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.Year
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# Name: Year, dtype: int64

# %%
gas['France']
# Out:
# 0     3.63
# 1     3.45
# 2     3.56
# 3     3.41
# 4     3.59
# 5     4.26
# 6     4.41
# 7     4.00
# 8     3.87
# 9     3.85
# 10    3.80
# 11    3.51
# 12    3.62
# 13    4.35
# 14    4.99
# 15    5.46
# 16    5.88
# 17    6.60
# 18    7.51
# Name: France, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.plot(gas['Year'],gas['France'],color='g',marker='*',label='France')
plt.plot(gas['Year'],gas['UK'],color='k',marker='s',label='UK')
plt.plot(gas['Year'],gas['USA'],color='m',marker='+',label='USA')
plt.xlabel('Years')
plt.ylabel('Gas Prices')
plt.title('Gas Prices of countries over the years')
plt.xticks(gas['Year'],rotation=30)
plt.legend();

# %%
plt.figure(figsize=(12,5))
plt.plot(gas['Year'],gas['France'],color='g',marker='*',label='France')
plt.plot(gas['Year'],gas['UK'],color='k',marker='s',label='UK')
plt.plot(gas['Year'],gas['USA'],color='m',marker='+',label='USA')
plt.xlabel('Years',fontsize=14)
plt.grid()
plt.ylabel('Gas Prices',fontsize=14)
plt.title('Gas Prices of countries over the years',fontsize=16)
plt.xticks(gas['Year'])
plt.legend()
plt.savefig('ourlineplot.png');

# %% [markdown]
# ## Subplots
#
# * plt.subplot(n,m,i) <br>
# * plt.subplot(nmi)

# %% [markdown]
# ![Grid8.jpg](attachment:Grid8.jpg)

# %% [markdown]
# ![Grid3.jpg](attachment:Grid3.jpg)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.plot([2,4,6,8,10,15,20],[4,8,12,16,20,30,40])

plt.subplot(1,3,2)
plt.plot([2,4,6,8,10,15,20],[4,8,12,16,20,30,40])


plt.subplot(1,3,3)
plt.plot([2,4,6,8,10,15,20],[4,8,12,16,20,30,40])


plt.show()

# %%
salary = [200,100,800]
name = ['Dante','Mark','Joe']

# %%
plt.figure(figsize=(15,8))

plt.subplot(2,3,1)
plt.plot(gas['Year'],gas['France'],color='g',marker='*',label='France')
plt.plot(gas['Year'],gas['UK'],color='k',marker='s',label='UK')
plt.plot(gas['Year'],gas['USA'],color='m',marker='+',label='USA')
plt.xlabel('Years',fontsize=14)
plt.grid()
plt.ylabel('Gas Prices',fontsize=14)
plt.title('Gas Prices of countries over the years')
plt.xticks(gas['Year'],rotation=90)
plt.legend()


plt.subplot(2,3,2)
plt.scatter(gas['UK'],gas['Japan'],marker='*',color='red')

plt.subplot(2,3,3)
sns.heatmap(gas.corr(),annot=True,cmap='Blues')

plt.subplot(2,3,4)
plt.barh(name,salary,color=['#9FC131','#005C53','green'])
plt.xlabel('Names')
plt.ylabel('Salaries')
plt.grid()
plt.title('Salary Comparism')

plt.subplot(2,3,5)
plt.bar(name,salary,color=['red','blue','green'])
plt.xlabel('Names')
plt.ylabel('Salaries')
plt.grid()
plt.title('Salary Comparism')

plt.subplot(2,3,6)
plt.pie(salary,labels=name,colors=['#005C53','#D6D58E','#9FC131'],
        autopct='%.0f%%',explode=[0,0.1,0])
plt.legend()
plt.title('our pie')
plt.suptitle('Tertiary  Visualizations using Matplotlib',fontsize=16)
plt.tight_layout()
plt.show()

# %%
# ?plt.suptitle

# %% [markdown]
# ## Pie Plot

# %%
# ?plt.

# %%
plt.figure(figsize=(7,7))
plt.pie(salary,labels=name,colors=['#005C53','#D6D58E','#9FC131'],
        autopct='%.0f%%',explode=[0,0.1,0],shadow=True,
       startangle=90, textprops={'fontsize':16})
plt.legend()
plt.title('our pie');

# %% [markdown]
# ## Bar plot

# %%
# ?plt.bar

# %%
plt.bar(name,salary,color=['red','blue','green'])
plt.xlabel('Names')
plt.ylabel('Salaries')
plt.grid()
plt.title('Salary Comparism');

# %%
plt.barh(name,salary)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(name,salary,color=['#9FC131','#005C53','green'])
plt.xlabel('Names')
plt.ylabel('Salaries')
plt.grid()
plt.title('Salary Comparism')
# Out:
# Text(0.5, 1.0, 'Salary Comparism')

# %% [markdown]
# ## Scatter Plot

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
x = np.linspace(10,15,20)

# %%
y = np.random.rand(20)

# %%
plt.scatter(x,y,marker='s',color='black')
plt.plot(x,2.5*y-1)
plt.title('hahaha');

# %%
gas[gas['UK']>2][['UK']]
# Out:
#       UK
# 0   2.82
# 1   3.01
# 2   3.06
# 3   2.84
# 4   2.99
# 5   3.21
# 6   3.34
# 7   3.83
# 8   4.06
# 9   4.29
# 10  4.58
# 11  4.13
# 12  4.16
# 13  4.70
# 14  5.56
# 15  5.97
# 16  6.36
# 17  7.13
# 18  7.42

# %%
plt.scatter(gas['UK'],gas['Japan'],marker='*',color='red')

# %% [markdown]
# * plt.plot
# * plt.bar
# * plt.scatter
# * plt.hist
# * plt.pie
# * plt.subplot

# %% [markdown]
# ## Histogram

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.hist(gas['USA'],color='m');

# %%
# ?plt.hist

# %% [markdown]
# ## Pandas Plotting

# %%
gas['UK'].plot()
# Out:
# <AxesSubplot:>

# %%
gas['UK'].plot(kind='bar')
plt.title('pandas ploting')
# Out:
# Text(0.5, 1.0, 'pandas ploting')

# %%
gas['UK'].plot(kind='barh')
plt.title('pandas ploting')
# Out:
# Text(0.5, 1.0, 'pandas ploting')

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.barplot(gas['Year'],gas['UK'])
# Out:
# C:\Users\MTL9\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='UK'>

# %%
sns.barplot(data=gas,x='Year',y='UK')
plt.xticks(rotation=50);

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=gas,x='Year',y='UK',palette='cool')
plt.title('Makola analysis');

# %%
# ?sns.barplot

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=gas,x='Year',y='UK',color='Red')
plt.title('Makola analysis');

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=gas,x='Year',y='UK',palette='Pastel1')
plt.title('Makola analysis');

# %%
sns.histplot(gas['USA'])
# Out:
# <AxesSubplot:xlabel='USA', ylabel='Count'>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(data=iris,x='sepal_length',y='petal_length',hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.displot(gas['UK'])

# %%
sns.kdeplot(gas['UK'])

# %%
sns.countplot(iris['species'])
# Out:
# C:\Users\MTL9\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(data=gas,x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
gas.corr()
# Out:
#                  Year  Australia    Canada    France   Germany     Italy  \
# Year         1.000000   0.761861  0.743494  0.783013  0.850042  0.650927
# Australia    0.761861   1.000000  0.984879  0.980250  0.976130  0.982878
# Canada       0.743494   0.984879  1.000000  0.945870  0.935075  0.970192
# France       0.783013   0.980250  0.945870  1.000000  0.981924  0.951436
# Germany      0.850042   0.976130  0.935075  0.981924  1.000000  0.920420
# Italy        0.650927   0.982878  0.970192  0.951436  0.920420  1.000000
# Japan        0.450672   0.790025  0.743415  0.774489  0.777531  0.731602
# Mexico       0.916437   0.651233  0.691224  0.625543  0.721284  0.547230
# South Korea  0.949350   0.884736  0.865753  0.870020  0.913963  0.776858
# UK           0.940524   0.905756  0.904195  0.913211  0.937122  0.843946
# USA          0.841465   0.975917  0.983083  0.958066  0.965215  0.932612
#
#                 Japan    Mexico  South Korea        UK       USA
# ...

# %%
sns.heatmap(gas.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# ?sns.heatmap
