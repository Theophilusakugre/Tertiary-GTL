# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:theo1994@localhost/employees')

# %%
connection =engine.connect()

# %%
query="select * from employees"

# %%
employees = pd.read_sql(query,connection)

# %%
employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
query2 = " select * from employees e join salaries s on e.emp_no=s.emp_no"

# %%
pd.read_sql(query2,connection)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  emp_no  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 1        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 2        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 3        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 4        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# ...        ...         ...        ...       ...    ...         ...     ...
# 967325  201771  1962-12-24   Fumitaka   Gammage      F  1985-10-13  201771
# 967326  201771  1962-12-24   Fumitaka   Gammage      F  1985-10-13  201771
# 967327  201771  1962-12-24   Fumitaka   Gammage      F  1985-10-13  201771
# 967328  201771  1962-12-24   Fumitaka   Gammage      F  1985-10-13  201771
# 967329  201771  1962-12-24   Fumitaka   Gammage      F  1985-10-13  201771
#
#         salary   from_date     to_date
# ...

# %%
connection.close()

# %% [markdown]
# ## Pandas Data cleaning
# * Renaming of columns
# * Re-arranging of column order
# * Removing text from a column
# * dealing with missing values
# * changing data types
# * Replacing text within a column
# * string operations
# * removing columns
# * dropping rows

# %%
fire = pd.read_csv('fires.csv',index_col=0)
fire.head()
# Out:
#     ano      mes estado   numero  encontro
# 0  1998  Janeiro   Acre  0 Fires  1/1/1998
# 1  1999  Janeiro   Acre  0 Fires  1/1/1999
# 2  2000  Janeiro   Acre  0 Fires  1/1/2000
# 3  2001  Janeiro   Acre  0 Fires  1/1/2001
# 4  2002  Janeiro   Acre  0 Fires  1/1/2002

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ano       6454 non-null   int64
#  1   mes       6454 non-null   object
#  2   estado    6454 non-null   object
#  3   numero    6322 non-null   object
#  4   encontro  6454 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 302.5+ KB

# %%
new_col = {'ano':'year',
           'mes':'month',
           'estado':'state',
           'numero':'number_of_fires',
           'encontro':'date'}

# %%
fire.rename(columns=new_col,inplace=True)

# %%
fire
# Out:
#       year     month      state number_of_fires      date
# 0     1998   Janeiro       Acre         0 Fires  1/1/1998
# 1     1999   Janeiro       Acre         0 Fires  1/1/1999
# 2     2000   Janeiro       Acre         0 Fires  1/1/2000
# 3     2001   Janeiro       Acre         0 Fires  1/1/2001
# 4     2002   Janeiro       Acre         0 Fires  1/1/2002
# ...    ...       ...        ...             ...       ...
# 6449  2012  Dezembro  Tocantins             128  1/1/2012
# 6450  2013  Dezembro  Tocantins              85  1/1/2013
# 6451  2014  Dezembro  Tocantins             223  1/1/2014
# 6452  2015  Dezembro  Tocantins             373  1/1/2015
# 6453  2016  Dezembro  Tocantins             119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
fire.year.nunique()
# Out:
# 20

# %%
fire.columns[[4,0,1,2,3]]
# Out:
# Index(['date', 'year', 'month', 'state', 'number_of_fires'], dtype='object')

# %%
fire = fire[fire.columns[[4,0,1,2,3]]]

# %%
fire
# Out:
#           date  year     month      state number_of_fires
# 0     1/1/1998  1998   Janeiro       Acre         0 Fires
# 1     1/1/1999  1999   Janeiro       Acre         0 Fires
# 2     1/1/2000  2000   Janeiro       Acre         0 Fires
# 3     1/1/2001  2001   Janeiro       Acre         0 Fires
# 4     1/1/2002  2002   Janeiro       Acre         0 Fires
# ...        ...   ...       ...        ...             ...
# 6449  1/1/2012  2012  Dezembro  Tocantins             128
# 6450  1/1/2013  2013  Dezembro  Tocantins              85
# 6451  1/1/2014  2014  Dezembro  Tocantins             223
# 6452  1/1/2015  2015  Dezembro  Tocantins             373
# 6453  1/1/2016  2016  Dezembro  Tocantins             119
#
# [6454 rows x 5 columns]

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             6454 non-null   object
#  1   year             6454 non-null   int64
#  2   month            6454 non-null   object
#  3   state            6454 non-null   object
#  4   number_of_fires  6322 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 302.5+ KB

# %%
fire['number_of_fires'].str.isnumeric()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6449     True
# 6450     True
# 6451     True
# 6452     True
# 6453     True
# Name: number_of_fires, Length: 6454, dtype: object

# %%
fire['number_of_fires']
# Out:
# 0       0 Fires
# 1       0 Fires
# 2       0 Fires
# 3       0 Fires
# 4       0 Fires
#          ...
# 6449        128
# 6450         85
# 6451        223
# 6452        373
# 6453        119
# Name: number_of_fires, Length: 6454, dtype: object

# %%
float('2dsds')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22484\2591743867.py in <module>
# ----> 1 float('2dsds')
#
# ValueError: could not convert string to float: '2dsds'

# %%
fire['number_of_fires'] = fire['number_of_fires'].str.strip('Fires')

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             6454 non-null   object
#  1   year             6454 non-null   int64
#  2   month            6454 non-null   object
#  3   state            6454 non-null   object
#  4   number_of_fires  6322 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 302.5+ KB

# %%
fire['number_of_fires'] = fire['number_of_fires'].astype(float)

# %%
fire['date']= pd.to_datetime(fire['date'])

# %%
fire['date'].dt.dayofweek
# Out:
# 0       3
# 1       4
# 2       5
# 3       0
# 4       1
#        ..
# 6449    6
# 6450    1
# 6451    2
# 6452    3
# 6453    4
# Name: date, Length: 6454, dtype: int64

# %% [markdown]
# ## Handling missing data
# * removing missing data
# * replace them

# %%
fire.isna().sum()
# Out:
# date                 0
# year                 0
# month                0
# state                0
# number_of_fires    132
# dtype: int64

# %%
fire1= fire

# %%
fire1.isna().sum()
# Out:
# date               0
# year               0
# month              0
# state              0
# number_of_fires    0
# dtype: int64

# %%
fire1.dropna(inplace=True)

# %%
fire1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6322 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             6322 non-null   datetime64[ns]
#  1   year             6322 non-null   int64
#  2   month            6322 non-null   object
#  3   state            6322 non-null   object
#  4   number_of_fires  6322 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 296.3+ KB

# %%
fire1.tail(50)
# Out:
#            date  year     month      state  number_of_fires
# 6402 2005-01-01  2005   Outubro  Tocantins            2.913
# 6403 2006-01-01  2006   Outubro  Tocantins            1.176
# 6404 2007-01-01  2007   Outubro  Tocantins            2.252
# 6405 2008-01-01  2008   Outubro  Tocantins            2.832
# 6406 2009-01-01  2009   Outubro  Tocantins          718.000
# 6407 2010-01-01  2010   Outubro  Tocantins            2.272
# 6408 2011-01-01  2011   Outubro  Tocantins            1.591
# 6409 2012-01-01  2012   Outubro  Tocantins            3.680
# 6410 2013-01-01  2013   Outubro  Tocantins            2.155
# 6411 2014-01-01  2014   Outubro  Tocantins            4.000
# 6412 2015-01-01  2015   Outubro  Tocantins            4.844
# 6413 2016-01-01  2016   Outubro  Tocantins            2.032
# 6414 2017-01-01  2017   Outubro  Tocantins            2.969
# 6416 1999-01-01  1999  Novembro  Tocantins           29.000
# 6417 2000-01-01  2000  Novembro  Tocantins           96.000
# ...

# %%
fire2 = fire

# %%
fire2.isna().sum()
# Out:
# date               0
# year               0
# month              0
# state              0
# number_of_fires    0
# dtype: int64

# %%
fire2['number_of_fires'].fillna(0,inplace=True)

# %%
fire.isna().sum()
# Out:
# date               0
# year               0
# month              0
# state              0
# number_of_fires    0
# dtype: int64

# %%
fire3 = fire

# %%
fire3[fire3['number_of_fires'].isna()]
# Out:
#            date  year     month      state  number_of_fires
# 68   2006-01-01  2006     Abril       Acre              NaN
# 110  2008-01-01  2008     Junho       Acre              NaN
# 127  2005-01-01  2005     Julho       Acre              NaN
# 206  2004-01-01  2004  Novembro       Acre              NaN
# 217  2015-01-01  2015  Novembro       Acre              NaN
# ...         ...   ...       ...        ...              ...
# 6305 2008-01-01  2008      Maio  Tocantins              NaN
# 6354 2017-01-01  2017     Julho  Tocantins              NaN
# 6383 2006-01-01  2006  Setembro  Tocantins              NaN
# 6415 1998-01-01  1998  Novembro  Tocantins              NaN
# 6428 2011-01-01  2011  Novembro  Tocantins              NaN
#
# [132 rows x 5 columns]

# %%
fire3.iloc[67]
# Out:
# date               2005-01-01 00:00:00
# year                              2005
# month                            Abril
# state                             Acre
# number_of_fires                    1.0
# Name: 67, dtype: object

# %%
fire3.iloc[69]
# Out:
# date               2007-01-01 00:00:00
# year                              2007
# month                            Abril
# state                             Acre
# number_of_fires                    0.0
# Name: 69, dtype: object

# %%
fire3.iloc[68]
# Out:
# date               2006-01-01 00:00:00
# year                              2006
# month                            Abril
# state                             Acre
# number_of_fires                    NaN
# Name: 68, dtype: object

# %%
fire3['number_of_fires'].fillna(method='ffill').iloc[68]
# Out:
# 1.0

# %%
fire3['number_of_fires'].fillna(method='backfill').iloc[68]
# Out:
# 0.0

# %%
fire.head()
# Out:
#         date  year    month state  number_of_fires
# 0 1998-01-01  1998  Janeiro  Acre              0.0
# 1 1999-01-01  1999  Janeiro  Acre              0.0
# 2 2000-01-01  2000  Janeiro  Acre              0.0
# 3 2001-01-01  2001  Janeiro  Acre              0.0
# 4 2002-01-01  2002  Janeiro  Acre              0.0

# %%
fire.month.unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'], dtype=object)

# %%
months = {'Janeiro':'Jan', 'Fevereiro':'Feb', 'Março':'Mar', 'Abril':'Apr', 
          'Maio':'May', 'Junho':'Jun', 'Julho':'Jul',
       'Agosto':'Aug', 'Setembro':'Sep', 'Outubro':'Oct', 'Novembro':'Nov', 'Dezembro':'Dec'}

# %%
fire['month']= fire['month'].map(months)

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             6454 non-null   datetime64[ns]
#  1   year             6454 non-null   int64
#  2   month            6454 non-null   object
#  3   state            6454 non-null   object
#  4   number_of_fires  6322 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 302.5+ KB

# %%
fire['day'] = fire['date'].dt.dayofweek

# %%
fire.head()
# Out:
#         date  year month state  number_of_fires  day
# 0 1998-01-01  1998   Jan  Acre              0.0    3
# 1 1999-01-01  1999   Jan  Acre              0.0    4
# 2 2000-01-01  2000   Jan  Acre              0.0    5
# 3 2001-01-01  2001   Jan  Acre              0.0    0
# 4 2002-01-01  2002   Jan  Acre              0.0    1

# %%
fire.drop('date',axis=1)
# Out:
#       year month      state  number_of_fires  day
# 0     1998   Jan       Acre              0.0    3
# 1     1999   Jan       Acre              0.0    4
# 2     2000   Jan       Acre              0.0    5
# 3     2001   Jan       Acre              0.0    0
# 4     2002   Jan       Acre              0.0    1
# ...    ...   ...        ...              ...  ...
# 6449  2012   Dec  Tocantins            128.0    6
# 6450  2013   Dec  Tocantins             85.0    1
# 6451  2014   Dec  Tocantins            223.0    2
# 6452  2015   Dec  Tocantins            373.0    3
# 6453  2016   Dec  Tocantins            119.0    4
#
# [6454 rows x 5 columns]

# %%
fire.drop(['year','day','state'],axis=1,inplace=True)

# %%
fire
# Out:
#            date month  number_of_fires
# 0    1998-01-01   Jan              0.0
# 1    1999-01-01   Jan              0.0
# 2    2000-01-01   Jan              0.0
# 3    2001-01-01   Jan              0.0
# 4    2002-01-01   Jan              0.0
# ...         ...   ...              ...
# 6449 2012-01-01   Dec            128.0
# 6450 2013-01-01   Dec             85.0
# 6451 2014-01-01   Dec            223.0
# 6452 2015-01-01   Dec            373.0
# 6453 2016-01-01   Dec            119.0
#
# [6454 rows x 3 columns]

# %%
fire.index[4]
# Out:
# 4

# %%
fire.drop([2,5])
# Out:
#            date month  number_of_fires
# 0    1998-01-01   Jan              0.0
# 1    1999-01-01   Jan              0.0
# 3    2001-01-01   Jan              0.0
# 4    2002-01-01   Jan              0.0
# 6    2004-01-01   Jan              0.0
# ...         ...   ...              ...
# 6449 2012-01-01   Dec            128.0
# 6450 2013-01-01   Dec             85.0
# 6451 2014-01-01   Dec            223.0
# 6452 2015-01-01   Dec            373.0
# 6453 2016-01-01   Dec            119.0
#
# [6452 rows x 3 columns]

# %%
fire.drop(fire.index[2:6])
# Out:
#            date month  number_of_fires
# 0    1998-01-01   Jan              0.0
# 1    1999-01-01   Jan              0.0
# 6    2004-01-01   Jan              0.0
# 7    2005-01-01   Jan             12.0
# 8    2006-01-01   Jan              4.0
# ...         ...   ...              ...
# 6449 2012-01-01   Dec            128.0
# 6450 2013-01-01   Dec             85.0
# 6451 2014-01-01   Dec            223.0
# 6452 2015-01-01   Dec            373.0
# 6453 2016-01-01   Dec            119.0
#
# [6450 rows x 3 columns]
